# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nifty50-stock-market-data/HDFCBANK.csv
# /kaggle/input/nifty50-stock-market-data/GRASIM.csv
# /kaggle/input/nifty50-stock-market-data/WIPRO.csv
# /kaggle/input/nifty50-stock-market-data/stock_metadata.csv
# /kaggle/input/nifty50-stock-market-data/BPCL.csv
# /kaggle/input/nifty50-stock-market-data/INFY.csv
# /kaggle/input/nifty50-stock-market-data/LT.csv
# /kaggle/input/nifty50-stock-market-data/RELIANCE.csv
# /kaggle/input/nifty50-stock-market-data/BRITANNIA.csv
# /kaggle/input/nifty50-stock-market-data/INFRATEL.csv
# /kaggle/input/nifty50-stock-market-data/HEROMOTOCO.csv
# /kaggle/input/nifty50-stock-market-data/HINDUNILVR.csv
# /kaggle/input/nifty50-stock-market-data/TATAMOTORS.csv
# /kaggle/input/nifty50-stock-market-data/MM.csv
# /kaggle/input/nifty50-stock-market-data/HDFC.csv
# /kaggle/input/nifty50-stock-market-data/JSWSTEEL.csv
# /kaggle/input/nifty50-stock-market-data/TITAN.csv
# /kaggle/input/nifty50-stock-market-data/HINDALCO.csv
# /kaggle/input/nifty50-stock-market-data/AXISBANK.csv
# /kaggle/input/nifty50-stock-market-data/HCLTECH.csv
# /kaggle/input/nifty50-stock-market-data/ADANIPORTS.csv
# /kaggle/input/nifty50-stock-market-data/GAIL.csv
# /kaggle/input/nifty50-stock-market-data/NIFTY50_all.csv
# /kaggle/input/nifty50-stock-market-data/BAJAJFINSV.csv
# /kaggle/input/nifty50-stock-market-data/BAJFINANCE.csv
# /kaggle/input/nifty50-stock-market-data/ICICIBANK.csv
# /kaggle/input/nifty50-stock-market-data/ZEEL.csv
# /kaggle/input/nifty50-stock-market-data/ASIANPAINT.csv
# /kaggle/input/nifty50-stock-market-data/IOC.csv
# /kaggle/input/nifty50-stock-market-data/TATASTEEL.csv
# /kaggle/input/nifty50-stock-market-data/COALINDIA.csv
# /kaggle/input/nifty50-stock-market-data/NESTLEIND.csv
# /kaggle/input/nifty50-stock-market-data/DRREDDY.csv
# /kaggle/input/nifty50-stock-market-data/ONGC.csv
# /kaggle/input/nifty50-stock-market-data/EICHERMOT.csv
# /kaggle/input/nifty50-stock-market-data/UPL.csv
# /kaggle/input/nifty50-stock-market-data/SUNPHARMA.csv
# /kaggle/input/nifty50-stock-market-data/ULTRACEMCO.csv
# /kaggle/input/nifty50-stock-market-data/CIPLA.csv
# /kaggle/input/nifty50-stock-market-data/SHREECEM.csv
# /kaggle/input/nifty50-stock-market-data/VEDL.csv
# /kaggle/input/nifty50-stock-market-data/TCS.csv
# /kaggle/input/nifty50-stock-market-data/NTPC.csv
# /kaggle/input/nifty50-stock-market-data/MARUTI.csv
# /kaggle/input/nifty50-stock-market-data/KOTAKBANK.csv
# /kaggle/input/nifty50-stock-market-data/ITC.csv
# /kaggle/input/nifty50-stock-market-data/BAJAJ-AUTO.csv
# /kaggle/input/nifty50-stock-market-data/SBIN.csv
# /kaggle/input/nifty50-stock-market-data/INDUSINDBK.csv
# /kaggle/input/nifty50-stock-market-data/BHARTIARTL.csv
# /kaggle/input/nifty50-stock-market-data/TECHM.csv
# /kaggle/input/nifty50-stock-market-data/POWERGRID.csv

# %%
df=pd.read_csv("/kaggle/input/nifty50-stock-market-data/NIFTY50_all.csv")

# %% [markdown]
# Nifty 50 companies list Keeps shuffling their stocks quarterly at least 2 to 3 stocks are changed. This is the reason we find 65 companies over the 10 years span.

# %%
df.isnull().sum()
# Out:
# Date                       0
# Symbol                     0
# Series                     0
# Prev Close                 0
# Open                       0
# High                       0
# Low                        0
# Last                       0
# Close                      0
# VWAP                       0
# Volume                     0
# Turnover                   0
# Trades                114848
# Deliverable Volume     16077
# %Deliverble            16077
# dtype: int64

# %%
df.Symbol.unique()
# Out:
# array(['MUNDRAPORT', 'ADANIPORTS', 'ASIANPAINT', 'UTIBANK', 'AXISBANK',
#        'BAJAJ-AUTO', 'BAJAJFINSV', 'BAJAUTOFIN', 'BAJFINANCE', 'BHARTI',
#        'BHARTIARTL', 'BPCL', 'BRITANNIA', 'CIPLA', 'COALINDIA', 'DRREDDY',
#        'EICHERMOT', 'GAIL', 'GRASIM', 'HCLTECH', 'HDFC', 'HDFCBANK',
#        'HEROHONDA', 'HEROMOTOCO', 'HINDALC0', 'HINDALCO', 'HINDLEVER',
#        'HINDUNILVR', 'ICICIBANK', 'INDUSINDBK', 'INFOSYSTCH', 'INFY',
#        'IOC', 'ITC', 'JSWSTL', 'JSWSTEEL', 'KOTAKMAH', 'KOTAKBANK', 'LT',
#        'M&M', 'MARUTI', 'NESTLEIND', 'NTPC', 'ONGC', 'POWERGRID',
#        'RELIANCE', 'SBIN', 'SHREECEM', 'SUNPHARMA', 'TELCO', 'TATAMOTORS',
#        'TISCO', 'TATASTEEL', 'TCS', 'TECHM', 'TITAN', 'ULTRACEMCO',
#        'UNIPHOS', 'UPL', 'SESAGOA', 'SSLT', 'VEDL', 'WIPRO', 'ZEETELE',
#        'ZEEL'], dtype=object)

# %%
df
# Out:
#               Date      Symbol Series  Prev Close    Open     High     Low  \
# 0       2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1       2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2       2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3       2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4       2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...            ...         ...    ...         ...     ...      ...     ...
# 235187  2021-04-26        ZEEL     EQ      188.00  190.60   191.10  185.10
# 235188  2021-04-27        ZEEL     EQ      186.40  188.00   192.95  186.80
# 235189  2021-04-28        ZEEL     EQ      188.15  188.80   190.60  187.10
# 235190  2021-04-29        ZEEL     EQ      189.10  190.80   191.65  186.00
# 235191  2021-04-30        ZEEL     EQ      186.55  185.30   190.95  183.65
#
#           Last   Close    VWAP    Volume      Turnover   Trades  \
# 0       959.00  962.90  984.72  27294366  2.687719e+15      NaN
# 1       885.00  893.90  941.38   4581338  4.312765e+14      NaN
# 2       887.00  884.20  888.09   5124121  4.550658e+14      NaN
# 3       929.00  921.55  929.17   4609762  4.283257e+14      NaN
# 4       980.00  969.30  965.65   2977470  2.875200e+14      NaN
# ...        ...     ...     ...       ...           ...      ...
# 235187  186.70  186.40  187.35   8542755  1.600451e+14  52374.0
# 235188  188.80  188.15  189.41  14247767  2.698636e+14  73673.0
# 235189  188.95  189.10  188.85   8429439  1.591917e+14  44056.0
# 235190  186.60  186.55  187.44   9483009  1.777471e+14  60932.0
# 235191  185.00  185.60  187.53  11435285  2.144440e+14  62607.0
#
#         Deliverable Volume  %Deliverble
# 0                9859619.0       0.3612
# 1                1453278.0       0.3172
# 2                1069678.0       0.2088
# 3                1260913.0       0.2735
# 4                 816123.0       0.2741
# ...                    ...          ...
# 235187           2340188.0       0.2739
# 235188           5425957.0       0.3808
# 235189           2413974.0       0.2864
# 235190           2744472.0       0.2894
# 235191           3323909.0       0.2907
#
# [235192 rows x 15 columns]

# %%
df_check=df[df["Deliverable Volume"].isnull()]

# %%
df_check
# Out:
#               Date      Symbol Series  Prev Close    Open    High     Low  \
# 3322    2000-01-03  ASIANPAINT     EQ      361.20  370.00  390.00  370.00
# 3323    2000-01-04  ASIANPAINT     EQ      381.65  380.00  392.00  375.00
# 3324    2000-01-05  ASIANPAINT     EQ      385.55  371.50  390.00  371.50
# 3325    2000-01-06  ASIANPAINT     EQ      383.00  384.90  384.90  374.50
# 3326    2000-01-07  ASIANPAINT     EQ      377.50  376.00  390.00  370.00
# ...            ...         ...    ...         ...     ...     ...     ...
# 231671  2007-02-12     ZEETELE     EQ      361.30  225.25  319.40  225.25
# 231672  2007-02-13     ZEETELE     EQ      258.35  260.00  276.95  252.25
# 231673  2007-02-14     ZEETELE     EQ      267.95  272.00  277.00  256.50
# 231674  2007-02-15     ZEETELE     EQ      265.50  269.90  273.50  265.10
# 231675  2007-02-19     ZEETELE     EQ      268.25  269.25  272.00  258.25
#
#           Last   Close    VWAP   Volume      Turnover  Trades  \
# 3322    385.00  381.65  380.54     3318  1.262617e+11     NaN
# 3323    390.00  385.55  383.50     4818  1.847699e+11     NaN
# 3324    383.00  383.00  379.81     2628  9.981384e+10     NaN
# 3325    375.10  377.50  379.88     3354  1.274114e+11     NaN
# 3326    389.00  385.70  383.38     9589  3.676275e+11     NaN
# ...        ...     ...     ...      ...           ...     ...
# 231671  257.00  258.35  265.73  4429894  1.177153e+14     NaN
# 231672  272.55  267.95  269.91  2689950  7.260378e+13     NaN
# 231673  265.50  265.50  263.25  2820444  7.424754e+13     NaN
# 231674  268.00  268.25  268.78  3516748  9.452372e+13     NaN
# 231675  260.00  260.50  263.60  1381008  3.640377e+13     NaN
#
#         Deliverable Volume  %Deliverble
# 3322                   NaN          NaN
# 3323                   NaN          NaN
# 3324                   NaN          NaN
# 3325                   NaN          NaN
# 3326                   NaN          NaN
# ...                    ...          ...
# 231671                 NaN          NaN
# 231672                 NaN          NaN
# 231673                 NaN          NaN
# 231674                 NaN          NaN
# 231675                 NaN          NaN
#
# [16077 rows x 15 columns]

# %% [markdown]
# In the DataFrame 'Series' has only 1 unique value as it is representing the type of trade and over the years only equities have been part of the Nifty50. The column Trade represents number of buy/sell order that took place ion the given trading day  and this information became part of the dataset starting from 2011. So essentitally almost decade of the data is missing as it was not part of the data collection. 'VWAP' represents weighted average price of the stock for the day 'Volume Weighted Average Price'

# %%
#df.drop(["Trades","Deliverable Volume","%Deliverble","Series"],inplace=True,axis=1)

# %%
df
# Out:
#               Date      Symbol Series  Prev Close    Open     High     Low  \
# 0       2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1       2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2       2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3       2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4       2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...            ...         ...    ...         ...     ...      ...     ...
# 235187  2021-04-26        ZEEL     EQ      188.00  190.60   191.10  185.10
# 235188  2021-04-27        ZEEL     EQ      186.40  188.00   192.95  186.80
# 235189  2021-04-28        ZEEL     EQ      188.15  188.80   190.60  187.10
# 235190  2021-04-29        ZEEL     EQ      189.10  190.80   191.65  186.00
# 235191  2021-04-30        ZEEL     EQ      186.55  185.30   190.95  183.65
#
#           Last   Close    VWAP    Volume      Turnover   Trades  \
# 0       959.00  962.90  984.72  27294366  2.687719e+15      NaN
# 1       885.00  893.90  941.38   4581338  4.312765e+14      NaN
# 2       887.00  884.20  888.09   5124121  4.550658e+14      NaN
# 3       929.00  921.55  929.17   4609762  4.283257e+14      NaN
# 4       980.00  969.30  965.65   2977470  2.875200e+14      NaN
# ...        ...     ...     ...       ...           ...      ...
# 235187  186.70  186.40  187.35   8542755  1.600451e+14  52374.0
# 235188  188.80  188.15  189.41  14247767  2.698636e+14  73673.0
# 235189  188.95  189.10  188.85   8429439  1.591917e+14  44056.0
# 235190  186.60  186.55  187.44   9483009  1.777471e+14  60932.0
# 235191  185.00  185.60  187.53  11435285  2.144440e+14  62607.0
#
#         Deliverable Volume  %Deliverble
# 0                9859619.0       0.3612
# 1                1453278.0       0.3172
# 2                1069678.0       0.2088
# 3                1260913.0       0.2735
# 4                 816123.0       0.2741
# ...                    ...          ...
# 235187           2340188.0       0.2739
# 235188           5425957.0       0.3808
# 235189           2413974.0       0.2864
# 235190           2744472.0       0.2894
# 235191           3323909.0       0.2907
#
# [235192 rows x 15 columns]

# %%
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff
import numpy as np
import plotly.graph_objects as go

# %%
def view_graph(symbol,price):
    import plotly.graph_objects as go
    df_sample=df[df["Symbol"]==str(symbol)]
    fig = go.Figure([go.Scatter(x=df_sample['Date'], y=df_sample[price])])
    fig.show()

# %%
view_graph(symbol='SBIN',price='Last')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1b81a775-4575-4e85-a3a1-101f4ceffd98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b81a775-4575-4e85-a3a1-101f4ceffd98")) {                    Plotly.newPlot(                        "1b81a775-4575-4e85-a3a1-101f4ceffd98",                        [{"type":"scatter","x":["2000-01-03T00:00:00","2000-01-04T00:00:00","2000-01-05T00:00:00","2000-01-06T00:00:00","2000-01-07T00:00:00","2000-01-10T00:00:00","2000-01-11T00:00:00","2000-01-12T00:00:00","2000-01-13T00:00:00","2000-01-14T00:00:00","2000-01-17T00:00:00","2000-01-18T00:00:00","2000-01-19T00:00:00","2000-01-20T00:00:00","2000-01-21T00:00:00","2000-01-24T00:00:00","2000-01-25T00:00:00","2000-01-27T00:00:00","2000-01-28T00:00:00","2000-01-31T00:00:00","2000-02-01T00:00:00","2000-02-02T00:00:00","2000-02-03T00:00:00","2000-02-04T00:00:00","2000-02-07T00:00:00","2000-02-08T00:00:00","2000-02-09T00:00:00","2000-02-10T00:00:00","2000-02-11T00:00:00","2000-02-14T00:00:00","2000-02-15T00:00:00","2000-02-16T00:00:00","2000-02-17T00:00:00","2000-02-18T00:00:00","2000-02-21T00:00:00","2000-02-22T00:00:00","2000-02-23T00:00:00","2000-02-24T00:00:00","2000-02-25T00:00:00","2000-02-28T00:00:00","2000-02-29T00:00:00","2000-03-01T00:00:00","2000-03-02T00:00:00","2000-03-03T00:00:00","2000-03-06T00:00:00","2000-03-07T00:00:00","2000-03-08T00:00:00","2000-03-09T00:00:00","2000-03-10T00:00:00","2000-03-13T00:00:00","2000-03-14T00:00:00","2000-03-15T00:00:00","2000-03-16T00:00:00","2000-03-21T00:00:00","2000-03-22T00:00:00","2000-03-23T00:00:00","2000-03-24T00:00:00","2000-03-27T00:00:00","2000-03-28T00:00:00","2000-03-29T00:00:00","2000-03-30T00:00:00","2000-03-31T00:00:00","2000-04-03T00:00:00","2000-04-04T00:00:00","2000-04-05T00:00:00","2000-04-06T00:00:00","2000-04-07T00:00:00","2000-04-10T00:00:00","2000-04-11T00:00:00","2000-04-12T00:00:00","2000-04-13T00:00:00","2000-04-17T00:00:00","2000-04-18T00:00:00","2000-04-19T00:00:00","2000-04-20T00:00:00","2000-04-24T00:00:00","2000-04-25T00:00:00","2000-04-26T00:00:00","2000-04-27T00:00:00","2000-04-28T00:00:00","2000-05-02T00:00:00","2000-05-03T00:00:00","2000-05-04T00:00:00","2000-05-05T00:00:00","2000-05-08T00:00:00","2000-05-09T00:00:00","2000-05-10T00:00:00","2000-05-11T00:00:00","2000-05-12T00:00:00","2000-05-15T00:00:00","2000-05-16T00:00:00","2000-05-17T00:00:00","2000-05-18T00:00:00","2000-05-19T00:00:00","2000-05-22T00:00:00","2000-05-23T00:00:00","2000-05-24T00:00:00","2000-05-25T00:00:00","2000-05-26T00:00:00","2000-05-29T00:00:00","2000-05-30T00:00:00","2000-05-31T00:00:00","2000-06-01T00:00:00","2000-06-02T00:00:00","2000-06-05T00:00:00","2000-06-06T00:00:00","2000-06-07T00:00:00","2000-06-08T00:00:00","2000-06-09T00:00:00","2000-06-12T00:00:00","2000-06-13T00:00:00","2000-06-14T00:00:00","2000-06-15T00:00:00","2000-06-16T00:00:00","2000-06-19T00:00:00","2000-06-20T00:00:00","2000-06-21T00:00:00","2000-06-22T00:00:00","2000-06-23T00:00:00","2000-06-26T00:00:00","2000-06-27T00:00:00","2000-06-28T00:00:00","2000-06-29T00:00:00","2000-06-30T00:00:00","2000-07-03T00:00:00","2000-07-04T00:00:00","2000-07-05T00:00:00","2000-07-06T00:00:00","2000-07-07T00:00:00","2000-07-10T00:00:00","2000-07-11T00:00:00","2000-07-12T00:00:00","2000-07-13T00:00:00","2000-07-14T00:00:00","2000-07-17T00:00:00","2000-07-18T00:00:00","2000-07-19T00:00:00","2000-07-20T00:00:00","2000-07-21T00:00:00","2000-07-24T00:00:00","2000-07-25T00:00:00","2000-07-26T00:00:00","2000-07-27T00:00:00","2000-07-28T00:00:00","2000-07-31T00:00:00","2000-08-01T00:00:00","2000-08-02T00:00:00","2000-08-03T00:00:00","2000-08-04T00:00:00","2000-08-07T00:00:00","2000-08-08T00:00:00","2000-08-09T00:00:00","2000-08-10T00:00:00","2000-08-11T00:00:00","2000-08-14T00:00:00","2000-08-16T00:00:00","2000-08-17T00 ...

# %%
from sklearn.preprocessing import MinMaxScaler

### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from keras.layers import Dropout

# %%
df
# Out:
#                  Date      Symbol Series  Prev Close    Open     High     Low  \
# Date
# 2007-11-27 2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 2007-11-28 2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2007-11-29 2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 2007-11-30 2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 2007-12-03 2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...               ...         ...    ...         ...     ...      ...     ...
# 2021-04-26 2021-04-26        ZEEL     EQ      188.00  190.60   191.10  185.10
# 2021-04-27 2021-04-27        ZEEL     EQ      186.40  188.00   192.95  186.80
# 2021-04-28 2021-04-28        ZEEL     EQ      188.15  188.80   190.60  187.10
# 2021-04-29 2021-04-29        ZEEL     EQ      189.10  190.80   191.65  186.00
# 2021-04-30 2021-04-30        ZEEL     EQ      186.55  185.30   190.95  183.65
#
#               Last   Close    VWAP    Volume      Turnover   Trades  \
# Date
# 2007-11-27  959.00  962.90  984.72  27294366  2.687719e+15      NaN
# 2007-11-28  885.00  893.90  941.38   4581338  4.312765e+14      NaN
# 2007-11-29  887.00  884.20  888.09   5124121  4.550658e+14      NaN
# 2007-11-30  929.00  921.55  929.17   4609762  4.283257e+14      NaN
# 2007-12-03  980.00  969.30  965.65   2977470  2.875200e+14      NaN
# ...            ...     ...     ...       ...           ...      ...
# 2021-04-26  186.70  186.40  187.35   8542755  1.600451e+14  52374.0
# 2021-04-27  188.80  188.15  189.41  14247767  2.698636e+14  73673.0
# 2021-04-28  188.95  189.10  188.85   8429439  1.591917e+14  44056.0
# 2021-04-29  186.60  186.55  187.44   9483009  1.777471e+14  60932.0
# 2021-04-30  185.00  185.60  187.53  11435285  2.144440e+14  62607.0
#
#             Deliverable Volume  %Deliverble
# Date
# 2007-11-27           9859619.0       0.3612
# 2007-11-28           1453278.0       0.3172
# 2007-11-29           1069678.0       0.2088
# 2007-11-30           1260913.0       0.2735
# 2007-12-03            816123.0       0.2741
# ...                        ...          ...
# 2021-04-26           2340188.0       0.2739
# 2021-04-27           5425957.0       0.3808
# 2021-04-28           2413974.0       0.2864
# 2021-04-29           2744472.0       0.2894
# 2021-04-30           3323909.0       0.2907
#
# [235192 rows x 15 columns]

# %%
df_RELIANCE = df[df["Symbol"]=='RELIANCE']

# %%
df_RELIANCE.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# dtype: int64

# %%
features = ["Date", "High"]
all_data = df_RELIANCE[features]

# %%
all_data
# Out:
#                  Date     High
# Date
# 2000-01-03 2000-01-03   251.70
# 2000-01-04 2000-01-04   271.85
# 2000-01-05 2000-01-05   287.90
# 2000-01-06 2000-01-06   300.70
# 2000-01-07 2000-01-07   317.90
# ...               ...      ...
# 2021-04-26 2021-04-26  1962.00
# 2021-04-27 2021-04-27  1997.20
# 2021-04-28 2021-04-28  2008.00
# 2021-04-29 2021-04-29  2044.50
# 2021-04-30 2021-04-30  2036.00
#
# [5306 rows x 2 columns]

# %%
#setting index
all_data.index = all_data.Date
all_data.drop('Date', axis=1, inplace=True)

# %%
all_data.head()
# Out:
#               High
# Date
# 2000-01-03  251.70
# 2000-01-04  271.85
# 2000-01-05  287.90
# 2000-01-06  300.70
# 2000-01-07  317.90

# %%
all_data.shape
# Out:
# (5306, 1)

# %%
#creating training and validation sets
dataset = all_data.values

train = dataset[2500:5000,:]
valid = dataset[4500:,:]

# %%
train.shape
# Out:
# (2500, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# %%
scaled_data.shape
# Out:
# (5306, 1)

# %%
x_train, y_train = [], []
for i in range(90,len(train)):
    x_train.append(scaled_data[i-90:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2410, 90)

# %%
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
x_train.shape
# Out:
# (2410, 90, 1)

# %%
#x_train.shape[1]

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(rate = 0.2))

model.add(LSTM(units=50, return_sequences = True))

model.add(LSTM(units=50, return_sequences = True))
model.add(Dropout(rate = 0.2))

model.add(LSTM(units=50, return_sequences = False))

model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 14s 206ms/step - loss: 0.0396
# Epoch 2/100
# 38/38 [==============================] - 8s 215ms/step - loss: 0.0020
# Epoch 3/100
# 38/38 [==============================] - 8s 210ms/step - loss: 0.0018
# Epoch 4/100
# 38/38 [==============================] - 8s 204ms/step - loss: 0.0017
# Epoch 5/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0016
# Epoch 6/100
# 38/38 [==============================] - 8s 210ms/step - loss: 0.0017
# Epoch 7/100
# 38/38 [==============================] - 8s 214ms/step - loss: 0.0018
# Epoch 8/100
# 38/38 [==============================] - 8s 202ms/step - loss: 0.0015
# Epoch 9/100
# 38/38 [==============================] - 8s 202ms/step - loss: 0.0016
# Epoch 10/100
# 38/38 [==============================] - 8s 206ms/step - loss: 0.0017
# Epoch 11/100
# 38/38 [==============================] - 8s 204ms/step - loss: 0.0014
# Epoch 12/100
# 38/38 [==============================] - 8s 206ms/step - loss: 0.0013
# Epoch 13/100
# 38/38 [==============================] - 8s 202ms/step - loss: 0.0015
# Epoch 14/100
# 38/38 [==============================] - 8s 204ms/step - loss: 0.0014
# Epoch 15/100
# 38/38 [==============================] - 8s 211ms/step - loss: 0.0011
# Epoch 16/100
# 38/38 [==============================] - 8s 216ms/step - loss: 0.0010
# Epoch 17/100
# 38/38 [==============================] - 8s 210ms/step - loss: 0.0010
# Epoch 18/100
# 38/38 [==============================] - 8s 210ms/step - loss: 0.0013
# Epoch 19/100
# 38/38 [==============================] - 8s 211ms/step - loss: 0.0010
# Epoch 20/100
# 38/38 [==============================] - 8s 215ms/step - loss: 9.7329e-04
# Epoch 21/100
# 38/38 [==============================] - 8s 209ms/step - loss: 0.0011
# Epoch 22/100
# 38/38 [==============================] - 8s 218ms/step - loss: 9.0688e-04
# Epoch 23/100
# 38/38 [==============================] - 8s 218ms/step - loss: 0.0010
# Epoch 24/100
# 38/38 [==============================] - 8s 208ms/step - loss: 9.7964e-04
# Epoch 25/100
# 38/38 [==============================] - 8s 206ms/step - loss: 8.6185e-04
# Epoch 26/100
# 38/38 [==============================] - 8s 206ms/step - loss: 8.3909e-04
# Epoch 27/100
# 38/38 [==============================] - 8s 214ms/step - loss: 8.4777e-04
# Epoch 28/100
# 38/38 [==============================] - 8s 212ms/step - loss: 8.3974e-04
# Epoch 29/100
# 38/38 [==============================] - 8s 212ms/step - loss: 7.4593e-04
# Epoch 30/100
# 38/38 [==============================] - 8s 213ms/step - loss: 7.6622e-04
# Epoch 31/100
# 38/38 [==============================] - 8s 219ms/step - loss: 7.0796e-04
# Epoch 32/100
# 38/38 [==============================] - 8s 213ms/step - loss: 8.3926e-04
# Epoch 33/100
# 38/38 [==============================] - 8s 222ms/step - loss: 6.1392e-04
# Epoch 34/100
# 38/38 [==============================] - 9s 249ms/step - loss: 8.4482e-04
# Epoch 35/100
# 38/38 [==============================] - 8s 220ms/step - loss: 7.8897e-04
# Epoch 36/100
# 38/38 [==============================] - 8s 210ms/step - loss: 7.7447e-04
# Epoch 37/100
# 38/38 [==============================] - 8s 208ms/step - loss: 6.2588e-04
# Epoch 38/100
# 38/38 [==============================] - 8s 206ms/step - loss: 7.3090e-04
# Epoch 39/100
# 38/38 [==============================] - 8s 214ms/step - loss: 7.1403e-04
# Epoch 40/100
# 38/38 [==============================] - 8s 210ms/step - loss: 6.9968e-04
# Epoch 41/100
# 38/38 [==============================] - 8s 217ms/step - loss: 4.9659e-04
# Epoch 42/100
# 38/38 [==============================] - 8s 212ms/step - loss: 8.0336e-04
# Epoch 43/100
# 38/38 [==============================] - 8s 220ms/step - loss: 6.1781e-04
# Epoch 44/100
# 38/38 [==============================] - 8s 216ms/step - loss: 6.6793e-04
# Epoch 45/100
# 38/38 [==============================] - 8s 211ms/step - loss: 7.4499e-04
# Epoch 46/100
# 38/38 [==============================] - 9s 235ms/step - loss: 7.7761e-04
# Epoch 47/100
# 38/38 [==============================] - 8s 217ms/step - loss: 6.6693e-04
# Epoch 48/100
# 38/38 [==============================] - 8s 212ms/step - loss: 5.5133e-04
# Epoch 49/100
# 38/38 [==============================] - 8s 210ms/step - loss: 6.0864e-04
# Epoch 50/100
# 38/38 [==============================] - 8s 207ms/step - loss: 4.5412e-04
# Epoch 51/100
# 38/38 [==============================] - 8s 212ms/step - loss: 6.2442e-04
# Epoch 52/100
# 38/38 [==============================] - 8s 209ms/step - loss: 6.2551e-04
# Epoch 53/100
# 38/38 [==============================] - 8s 209ms/step - loss: 8.6196e-04
# Epoch 54/100
# 38/38 [==============================] - 8s 208ms/step - loss: 5.6124e-04
# Epoch 55/100
# 38/38 [==============================] - 8s 215ms/step - loss: 4.5174e-04
# Epoch 56/100
# 38/38 [==============================] - 8s 210ms/step - loss: 3.5152e-04
# Epoch 57/100
# 38/38 [==============================] - 8s 209ms/step - loss: 6.8318e-04
# Epoch 58/100
# 38/38 [==============================] - 8s 211ms/step - loss: 4.9896e-04
# Epoch 59/100
# 38/38 [==============================] - 8s 214ms/step - loss: 4.9464e-04
# Epoch 60/100
# 38/38 [==============================] - 8s 212ms/step - loss: 4.4479e-04
# Epoch 61/100
# 38/38 [==============================] - 8s 217ms/step - loss: 4.2369e-04
# Epoch 62/100
# 38/38 [==============================] - 8s 211ms/step - loss: 6.6741e-04
# Epoch 63/100
# 38/38 [==============================] - 8s 211ms/step - loss: 4.3947e-04
# Epoch 64/100
# 38/38 [==============================] - 8s 208ms/step - loss: 4.3622e-04
# Epoch 65/100
# 38/38 [==============================] - 8s 207ms/step - loss: 4.9749e-04
# Epoch 66/100
# 38/38 [==============================] - 8s 207ms/step - loss: 3.6496e-04
# Epoch 67/100
# 38/38 [==============================] - 8s 208ms/step - loss: 4.6056e-04
# Epoch 68/100
# 38/38 [==============================] - 8s 218ms/step - loss: 4.8083e-04
# Epoch 69/100
# 38/38 [==============================] - 8s 219ms/step - loss: 4.1220e-04
# Epoch 70/100
# 38/38 [==============================] - 8s 212ms/step - loss: 4.5073e-04
# Epoch 71/100
# 38/38 [==============================] - 8s 210ms/step - loss: 3.8128e-04
# Epoch 72/100
# 38/38 [==============================] - 8s 216ms/step - loss: 5.5695e-04
# Epoch 73/100
# 38/38 [==============================] - 8s 213ms/step - loss: 3.6221e-04
# Epoch 74/100
# 38/38 [==============================] - 8s 212ms/step - loss: 4.9721e-04
# Epoch 75/100
# 38/38 [==============================] - 8s 208ms/step - loss: 4.3609e-04
# Epoch 76/100
# 38/38 [==============================] - 8s 213ms/step - loss: 4.1548e-04
# Epoch 77/100
# 38/38 [==============================] - 8s 209ms/step - loss: 3.8297e-04
# Epoch 78/100
# 38/38 [==============================] - 8s 208ms/step - loss: 3.4652e-04
# Epoch 79/100
# 38/38 [==============================] - 8s 207ms/step - loss: 3.8715e-04
# Epoch 80/100
# 38/38 [==============================] - 8s 213ms/step - loss: 4.5448e-04
# Epoch 81/100
# 38/38 [==============================] - 8s 209ms/step - loss: 4.9048e-04
# Epoch 82/100
# 38/38 [==============================] - 8s 210ms/step - loss: 4.9408e-04
# Epoch 83/100
# 38/38 [==============================] - 8s 208ms/step - loss: 4.1193e-04
# Epoch 84/100
# 38/38 [==============================] - 8s 215ms/step - loss: 3.2589e-04
# Epoch 85/100
# 38/38 [==============================] - 8s 211ms/step - loss: 4.4084e-04
# Epoch 86/100
# 38/38 [==============================] - 8s 207ms/step - loss: 6.9525e-04
# Epoch 87/100
# 38/38 [==============================] - 8s 209ms/step - loss: 4.9093e-04
# Epoch 88/100
# 38/38 [==============================] - 8s 217ms/step - loss: 4.5406e-04
# Epoch 89/100
# 38/38 [==============================] - 8s 210ms/step - loss: 5.2523e-04
# Epoch 90/100
# 38/38 [==============================] - 8s 206ms/step - loss: 3.1935e-04
# Epoch 91/100
# 38/38 [==============================] - 8s 215ms/step - loss: 2.8929e-04
# Epoch 92/100
# 38/38 [==============================] - 8s 212ms/step - loss: 5.3291e-04
# Epoch 93/100
# 38/38 [==============================] - 8s 210ms/step - loss: 4.1320e-04
# Epoch 94/100
# 38/38 [==============================] - 8s 209ms/step - loss: 3.7462e-04
# Epoch 95/100
# 38/38 [==============================] - 8s 207ms/step - loss: 5.4133e-04
# Epoch 96/100
# 38/38 [==============================] - 8s 215ms/step - loss: 4.7156e-04
# Epoch 97/100
# 38/38 [==============================] - 8s 210ms/step - loss: 4.2762e-04
# Epoch 98/100
# 38/38 [==============================] - 8s 207ms/step - loss: 3.5104e-04
# Epoch 99/100
# 38/38 [==============================] - 8s 210ms/step - loss: 4.8416e-04
# Epoch 100/100
# 38/38 [==============================] - 8s 215ms/step - loss: 2.9629e-04

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %%
#predicting test data values, using past 90 from the train data
inputs = all_data[len(all_data) - len(valid)-90:].values

# %%
inputs
# Out:
# array([[ 852.85],
#        [ 851.05],
#        [ 848.75],
#        [ 872.5 ],
#        [ 851.7 ],
#        [ 839.9 ],
#        [ 827.95],
#        [ 827.05],
#        [ 825.7 ],
#        [ 802.9 ],
#        [ 793.4 ],
#        [ 803.85],
#        [ 824.95],
#        [ 828.45],
#        [ 839.35],
#        [ 839.8 ],
#        [ 847.3 ],
#        [ 858.4 ],
#        [ 876.8 ],
#        [ 890.7 ],
#        [ 892.  ],
#        [ 884.  ],
#        [ 917.9 ],
#        [ 921.9 ],
#        [ 944.7 ],
#        [ 947.7 ],
#        [ 945.9 ],
#        [ 957.8 ],
#        [ 956.7 ],
#        [ 945.55],
#        [ 945.75],
#        [ 957.8 ],
#        [ 956.5 ],
#        [ 955.95],
#        [ 942.5 ],
#        [ 935.  ],
#        [ 906.  ],
#        [ 909.9 ],
#        [ 900.95],
#        [ 891.9 ],
#        [ 895.  ],
#        [ 890.6 ],
#        [ 906.  ],
#        [ 924.9 ],
#        [ 924.35],
#        [ 939.65],
#        [ 938.65],
#        [ 949.9 ],
#        [ 959.5 ],
#        [ 957.5 ],
#        [ 951.35],
#        [ 950.  ],
#        [ 941.45],
#        [ 931.25],
#        [ 913.8 ],
#        [ 920.75],
#        [ 930.3 ],
#        [ 936.  ],
#        [ 936.95],
#        [ 926.  ],
#        [ 929.  ],
#        [ 924.95],
#        [ 924.9 ],
#        [ 932.95],
#        [ 932.65],
#        [ 927.  ],
#        [ 927.4 ],
#        [ 923.95],
#        [ 922.4 ],
#        [ 938.9 ],
#        [ 937.5 ],
#        [ 934.4 ],
#        [ 932.3 ],
#        [ 922.7 ],
#        [ 919.55],
#        [ 926.  ],
#        [ 921.8 ],
#        [ 926.9 ],
#        [ 931.  ],
#        [ 943.9 ],
#        [ 947.4 ],
#        [ 942.65],
#        [ 952.8 ],
#        [ 958.5 ],
#        [ 947.7 ],
#        [ 929.  ],
#        [ 929.6 ],
#        [ 934.4 ],
#        [ 974.3 ],
#        [ 990.95],
#        [ 981.75],
#        [ 972.  ],
#        [ 977.3 ],
#        [ 965.8 ],
#        [ 964.5 ],
#        [ 972.6 ],
#        [ 943.95],
#        [ 912.5 ],
#        [ 898.  ],
#        [ 905.4 ],
#        [ 910.65],
#        [ 902.  ],
#        [ 918.2 ],
#        [ 942.5 ],
#        [ 945.75],
#        [ 942.6 ],
#        [ 932.  ],
#        [ 929.55],
#        [ 932.5 ],
#        [ 931.  ],
#        [ 938.  ],
#        [ 944.9 ],
#        [ 955.8 ],
#        [ 957.1 ],
#        [ 959.9 ],
#        [ 950.15],
#        [ 936.2 ],
#        [ 909.25],
#        [ 914.5 ],
#        [ 919.35],
#        [ 933.1 ],
#        [ 936.  ],
#        [ 932.05],
#        [ 929.45],
#        [ 909.7 ],
#        [ 906.9 ],
#        [ 904.  ],
#        [ 902.35],
#        [ 911.95],
#        [ 900.  ],
#        [ 904.3 ],
#        [ 910.75],
#        [ 895.85],
#        [ 900.95],
#        [ 901.7 ],
#        [ 911.8 ],
#        [ 910.  ],
#        [ 918.5 ],
#        [ 919.  ],
#        [ 923.9 ],
#        [ 932.75],
#        [ 936.65],
#        [ 941.7 ],
#        [ 940.  ],
#        [ 947.2 ],
#        [ 948.2 ],
#        [ 945.  ],
#        [ 941.85],
#        [ 944.35],
#        [ 975.7 ],
#        [ 981.8 ],
#        [ 988.  ],
#        [1011.  ],
#        [ 992.6 ],
#        [ 979.2 ],
#        [ 977.9 ],
#        [ 964.7 ],
#        [ 973.25],
#        [ 982.  ],
#        [ 984.3 ],
#        [ 984.6 ],
#        [ 991.3 ],
#        [ 991.95],
#        [1000.  ],
#        [ 974.  ],
#        [ 960.  ],
#        [ 953.5 ],
#        [ 935.7 ],
#        [ 934.  ],
#        [ 926.  ],
#        [ 921.  ],
#        [ 923.4 ],
#        [ 927.  ],
#        [ 928.  ],
#        [ 923.2 ],
#        [ 922.3 ],
#        [ 935.75],
#        [ 944.  ],
#        [ 955.  ],
#        [ 956.  ],
#        [ 976.  ],
#        [ 986.55],
#        [ 999.95],
#        [1000.  ],
#        [1005.9 ],
#        [1011.8 ],
#        [1023.5 ],
#        [1020.45],
#        [1014.8 ],
#        [1022.9 ],
#        [1036.  ],
#        [1029.2 ],
#        [1016.5 ],
#        [1006.  ],
#        [ 985.4 ],
#        [ 968.5 ],
#        [ 975.5 ],
#        [ 972.35],
#        [ 978.45],
#        [ 992.  ],
#        [1008.4 ],
#        [ 983.  ],
#        [1000.  ],
#        [1028.5 ],
#        [1040.9 ],
#        [1099.  ],
#        [1109.  ],
#        [1108.9 ],
#        [1095.95],
#        [1104.6 ],
#        [1115.  ],
#        [1138.5 ],
#        [1129.8 ],
#        [1126.75],
#        [1123.  ],
#        [1121.5 ],
#        [1137.4 ],
#        [1157.3 ],
#        [1190.4 ],
#        [1202.9 ],
#        [1191.5 ],
#        [1183.5 ],
#        [1196.  ],
#        [1201.4 ],
#        [1222.5 ],
#        [1231.7 ],
#        [1215.  ],
#        [1199.95],
#        [1217.2 ],
#        [1216.  ],
#        [1215.4 ],
#        [1236.8 ],
#        [1251.5 ],
#        [1274.  ],
#        [1279.95],
#        [1295.85],
#        [1323.  ],
#        [1329.  ],
#        [1297.15],
#        [1270.  ],
#        [1257.9 ],
#        [1254.8 ],
#        [1252.65],
#        [1265.7 ],
#        [1281.35],
#        [1277.  ],
#        [1268.4 ],
#        [1258.7 ],
#        [1275.6 ],
#        [1250.75],
#        [1239.4 ],
#        [1224.  ],
#        [1237.4 ],
#        [1239.9 ],
#        [1245.  ],
#        [1253.95],
#        [1263.  ],
#        [1271.7 ],
#        [1257.7 ],
#        [1239.6 ],
#        [1190.4 ],
#        [1115.3 ],
#        [1117.  ],
#        [1123.3 ],
#        [1115.85],
#        [1114.75],
#        [1129.  ],
#        [1146.9 ],
#        [1167.4 ],
#        [1179.35],
#        [1111.  ],
#        [1114.8 ],
#        [1064.7 ],
#        [1075.95],
#        [1040.65],
#        [1057.  ],
#        [1093.85],
#        [1085.5 ],
#        [1065.85],
#        [1067.9 ],
#        [1081.  ],
#        [1092.7 ],
#        [1112.  ],
#        [1115.  ],
#        [1113.8 ],
#        [1098.8 ],
#        [1103.  ],
#        [1112.65],
#        [1103.  ],
#        [1129.95],
#        [1151.7 ],
#        [1155.9 ],
#        [1145.5 ],
#        [1125.35],
#        [1117.5 ],
#        [1130.  ],
#        [1157.75],
#        [1179.9 ],
#        [1186.  ],
#        [1174.9 ],
#        [1158.  ],
#        [1158.8 ],
#        [1149.  ],
#        [1136.95],
#        [1114.3 ],
#        [1102.1 ],
#        [1113.5 ],
#        [1128.  ],
#        [1114.9 ],
#        [1133.  ],
#        [1139.  ],
#        [1147.3 ],
#        [1132.5 ],
#        [1131.25],
#        [1103.2 ],
#        [1100.  ],
#        [1127.  ],
#        [1135.25],
#        [1133.85],
#        [1127.3 ],
#        [1127.  ],
#        [1114.6 ],
#        [1104.45],
#        [1118.45],
#        [1109.95],
#        [1117.  ],
#        [1111.  ],
#        [1113.8 ],
#        [1100.5 ],
#        [1132.  ],
#        [1145.  ],
#        [1147.9 ],
#        [1189.9 ],
#        [1239.95],
#        [1246.95],
#        [1244.2 ],
#        [1253.2 ],
#        [1264.7 ],
#        [1255.95],
#        [1231.65],
#        [1225.  ],
#        [1229.7 ],
#        [1255.  ],
#        [1296.95],
#        [1304.4 ],
#        [1317.65],
#        [1321.2 ],
#        [1300.5 ],
#        [1276.  ],
#        [1272.35],
#        [1273.95],
#        [1241.  ],
#        [1249.9 ],
#        [1252.5 ],
#        [1239.7 ],
#        [1240.  ],
#        [1257.8 ],
#        [1245.3 ],
#        [1243.  ],
#        [1234.8 ],
#        [1244.9 ],
#        [1239.85],
#        [1242.35],
#        [1239.8 ],
#        [1273.1 ],
#        [1279.8 ],
#        [1274.45],
#        [1312.  ],
#        [1334.  ],
#        [1360.  ],
#        [1362.  ],
#        [1358.8 ],
#        [1357.95],
#        [1380.  ],
#        [1388.  ],
#        [1380.9 ],
#        [1336.85],
#        [1371.6 ],
#        [1377.95],
#        [1369.8 ],
#        [1376.85],
#        [1406.8 ],
#        [1403.1 ],
#        [1403.  ],
#        [1383.7 ],
#        [1363.9 ],
#        [1357.5 ],
#        [1340.7 ],
#        [1348.  ],
#        [1353.  ],
#        [1356.9 ],
#        [1348.95],
#        [1360.  ],
#        [1389.75],
#        [1367.  ],
#        [1373.  ],
#        [1394.8 ],
#        [1412.4 ],
#        [1395.95],
#        [1396.4 ],
#        [1413.9 ],
#        [1417.5 ],
#        [1402.8 ],
#        [1395.  ],
#        [1340.  ],
#        [1288.8 ],
#        [1277.7 ],
#        [1260.8 ],
#        [1269.35],
#        [1278.  ],
#        [1271.9 ],
#        [1276.95],
#        [1337.7 ],
#        [1367.  ],
#        [1359.7 ],
#        [1392.  ],
#        [1353.8 ],
#        [1337.5 ],
#        [1334.8 ],
#        [1333.3 ],
#        [1342.  ],
#        [1341.9 ],
#        [1367.25],
#        [1374.25],
#        [1361.9 ],
#        [1327.25],
#        [1327.  ],
#        [1334.5 ],
#        [1338.4 ],
#        [1334.7 ],
#        [1325.  ],
#        [1320.  ],
#        [1287.95],
#        [1302.  ],
#        [1300.  ],
#        [1296.  ],
#        [1276.45],
#        [1298.  ],
#        [1304.6 ],
#        [1296.9 ],
#        [1282.85],
#        [1272.65],
#        [1281.  ],
#        [1286.5 ],
#        [1291.  ],
#        [1290.5 ],
#        [1268.1 ],
#        [1283.5 ],
#        [1289.35],
#        [1289.8 ],
#        [1300.  ],
#        [1289.5 ],
#        [1294.9 ],
#        [1297.  ],
#        [1286.4 ],
#        [1272.95],
#        [1284.5 ],
#        [1293.9 ],
#        [1278.8 ],
#        [1269.05],
#        [1242.5 ],
#        [1222.  ],
#        [1220.  ],
#        [1185.  ],
#        [1188.2 ],
#        [1198.25],
#        [1167.  ],
#        [1149.6 ],
#        [1138.55],
#        [1158.  ],
#        [1175.5 ],
#        [1302.8 ],
#        [1304.45],
#        [1291.8 ],
#        [1296.8 ],
#        [1292.6 ],
#        [1278.65],
#        [1271.  ],
#        [1284.  ],
#        [1294.  ],
#        [1285.  ],
#        [1281.  ],
#        [1260.25],
#        [1254.4 ],
#        [1243.  ],
#        [1205.25],
#        [1213.2 ],
#        [1229.  ],
#        [1233.  ],
#        [1240.  ],
#        [1240.45],
#        [1228.5 ],
#        [1219.1 ],
#        [1211.  ],
#        [1216.3 ],
#        [1209.7 ],
#        [1269.9 ],
#        [1281.  ],
#        [1298.8 ],
#        [1295.  ],
#        [1298.8 ],
#        [1315.  ],
#        [1335.75],
#        [1342.  ],
#        [1314.7 ],
#        [1328.6 ],
#        [1320.8 ],
#        [1329.95],
#        [1369.  ],
#        [1365.6 ],
#        [1364.95],
#        [1370.  ],
#        [1379.65],
#        [1399.  ],
#        [1427.9 ],
#        [1436.85],
#        [1425.95],
#        [1441.4 ],
#        [1441.45],
#        [1445.  ],
#        [1480.  ],
#        [1484.55],
#        [1489.65],
#        [1461.8 ],
#        [1471.  ],
#        [1468.95],
#        [1446.45],
#        [1463.  ],
#        [1459.65],
#        [1444.25],
#        [1475.9 ],
#        [1481.6 ],
#        [1486.8 ],
#        [1486.  ],
#        [1514.9 ],
#        [1572.4 ],
#        [1556.  ],
#        [1569.5 ],
#        [1564.8 ],
#        [1576.35],
#        [1575.5 ],
#        [1584.15],
#        [1581.95],
#        [1614.45],
#        [1594.  ],
#        [1577.5 ],
#        [1579.75],
#        [1568.  ],
#        [1577.4 ],
#        [1573.6 ],
#        [1574.5 ],
#        [1573.85],
#        [1590.  ],
#        [1593.9 ],
#        [1579.  ],
#        [1580.  ],
#        [1614.9 ],
#        [1617.55],
#        [1577.55],
#        [1572.05],
#        [1552.95],
#        [1546.2 ],
#        [1547.65],
#        [1543.7 ],
#        [1527.1 ],
#        [1540.95],
#        [1541.65],
#        [1527.9 ],
#        [1534.5 ],
#        [1534.45],
#        [1550.  ],
#        [1557.95],
#        [1558.7 ],
#        [1550.  ],
#        [1539.9 ],
#        [1543.35],
#        [1584.95],
#        [1609.  ],
#        [1545.85],
#        [1546.75],
#        [1541.95],
#        [1536.35],
#        [1524.45],
#        [1510.  ],
#        [1494.4 ],
#        [1479.7 ],
#        [1453.25],
#        [1426.95],
#        [1399.95],
#        [1432.5 ],
#        [1452.8 ],
#        [1467.  ],
#        [1452.35],
#        [1445.5 ],
#        [1466.2 ],
#        [1474.85],
#        [1477.75],
#        [1501.45],
#        [1506.15],
#        [1475.9 ],
#        [1506.45],
#        [1508.  ],
#        [1477.  ],
#        [1451.4 ],
#        [1412.35],
#        [1393.8 ],
#        [1357.  ],
#        [1369.  ],
#        [1353.9 ],
#        [1353.8 ],
#        [1357.95],
#        [1288.15],
#        [1241.  ],
#        [1178.45],
#        [1101.  ],
#        [1140.  ],
#        [1079.7 ],
#        [1060.  ],
#        [1035.9 ],
#        [ 967.  ],
#        [1034.9 ],
#        [ 950.  ],
#        [ 970.  ],
#        [1151.55],
#        [1116.9 ],
#        [1107.3 ],
#        [1074.8 ],
#        [1129.8 ],
#        [1124.6 ],
#        [1134.45],
#        [1214.  ],
#        [1229.  ],
#        [1232.8 ],
#        [1215.  ],
#        [1236.  ],
#        [1187.45],
#        [1230.  ],
#        [1257.  ],
#        [1252.  ],
#        [1384.9 ],
#        [1385.85],
#        [1494.95],
#        [1475.  ],
#        [1455.45],
#        [1453.65],
#        [1494.95],
#        [1465.  ],
#        [1479.  ],
#        [1484.95],
#        [1513.65],
#        [1579.9 ],
#        [1615.  ],
#        [1568.35],
#        [1527.  ],
#        [1496.7 ],
#        [1466.7 ],
#        [1482.  ],
#        [1461.7 ],
#        [1446.85],
#        [1461.45],
#        [1458.  ],
#        [1449.7 ],
#        [1454.  ],
#        [1479.75],
#        [1472.  ],
#        [1538.35],
#        [1540.  ],
#        [1560.  ],
#        [1589.5 ],
#        [1618.  ],
#        [1618.4 ],
#        [1583.  ],
#        [1579.55],
#        [1567.95],
#        [1593.  ],
#        [1626.95],
#        [1648.55],
#        [1635.45],
#        [1665.  ],
#        [1788.8 ],
#        [1804.2 ],
#        [1763.75],
#        [1772.7 ],
#        [1749.  ],
#        [1752.  ],
#        [1739.75],
#        [1741.  ],
#        [1749.  ],
#        [1767.6 ],
#        [1793.  ],
#        [1858.  ],
#        [1864.35],
#        [1834.95],
#        [1835.  ],
#        [1884.6 ],
#        [1947.7 ],
#        [1941.7 ],
#        [1978.8 ],
#        [1869.  ],
#        [1920.  ],
#        [1932.  ],
#        [1977.  ],
#        [2010.  ],
#        [2079.7 ],
#        [2163.  ],
#        [2198.8 ],
#        [2194.  ],
#        [2182.8 ],
#        [2139.7 ],
#        [2129.  ],
#        [2057.  ],
#        [2167.  ],
#        [2196.  ],
#        [2167.7 ],
#        [2157.8 ],
#        [2165.  ],
#        [2160.  ],
#        [2145.  ],
#        [2138.9 ],
#        [2157.  ],
#        [2105.  ],
#        [2134.3 ],
#        [2154.  ],
#        [2123.9 ],
#        [2122.  ],
#        [2104.5 ],
#        [2111.3 ],
#        [2147.95],
#        [2150.  ],
#        [2132.9 ],
#        [2174.  ],
#        [2122.4 ],
#        [2138.  ],
#        [2138.75],
#        [2096.95],
#        [2105.75],
#        [2121.  ],
#        [2167.8 ],
#        [2344.95],
#        [2337.85],
#        [2360.  ],
#        [2325.75],
#        [2369.35],
#        [2333.7 ],
#        [2319.45],
#        [2336.  ],
#        [2277.  ],
#        [2276.75],
#        [2226.  ],
#        [2212.8 ],
#        [2238.  ],
#        [2264.  ],
#        [2267.  ],
#        [2263.8 ],
#        [2249.15],
#        [2233.9 ],
#        [2309.  ],
#        [2268.  ],
#        [2253.  ],
#        [2255.75],
#        [2285.75],
#        [2304.  ],
#        [2290.  ],
#        [2232.5 ],
#        [2228.7 ],
#        [2193.  ],
#        [2192.  ],
#        [2132.5 ],
#        [2135.  ],
#        [2101.95],
#        [2059.85],
#        [2057.7 ],
#        [2042.  ],
#        [2065.1 ],
#        [2027.  ],
#        [1909.  ],
#        [1929.  ],
#        [1960.95],
#        [2040.  ],
#        [2069.  ],
#        [2090.  ],
#        [2095.  ],
#        [2008.45],
#        [2036.65],
#        [2015.3 ],
#        [2085.  ],
#        [2006.5 ],
#        [2010.45],
#        [1983.8 ],
#        [1970.  ],
#        [1974.  ],
#        [1992.95],
#        [1965.  ],
#        [1956.1 ],
#        [1966.25],
#        [1962.  ],
#        [1981.1 ],
#        [1969.  ],
#        [1965.  ],
#        [2014.25],
#        [2033.8 ],
#        [2028.5 ],
#        [2038.  ],
#        [2015.  ],
#        [1989.7 ],
#        [1994.95],
#        [2005.  ],
#        [2004.9 ],
#        [2022.  ],
#        [1958.9 ],
#        [1951.45],
#        [1998.8 ],
#        [2018.  ],
#        [2012.3 ],
#        [2007.2 ],
#        [2011.9 ],
#        [1997.  ],
#        [1998.9 ],
#        [1983.6 ],
#        [1966.  ],
#        [1945.  ],
#        [1938.4 ],
#        [1938.8 ],
#        [1960.  ],
#        [1974.95],
#        [1966.9 ],
#        [1973.8 ],
#        [1997.  ],
#        [2031.  ],
#        [2058.  ],
#        [2120.  ],
#        [2115.35],
#        [2034.95],
#        [1925.  ],
#        [1923.3 ],
#        [1913.1 ],
#        [1905.  ],
#        [1940.  ],
#        [1952.  ],
#        [1940.  ],
#        [1944.65],
#        [1969.  ],
#        [1989.6 ],
#        [1984.75],
#        [2064.2 ],
#        [2078.  ],
#        [2061.3 ],
#        [2079.4 ],
#        [2095.95],
#        [2108.4 ],
#        [2104.95],
#        [2089.9 ],
#        [2052.9 ],
#        [2065.25],
#        [2152.  ],
#        [2133.9 ],
#        [2112.  ],
#        [2130.  ],
#        [2219.9 ],
#        [2189.95],
#        [2211.95],
#        [2231.9 ],
#        [2213.8 ],
#        [2215.1 ],
#        [2206.4 ],
#        [2148.9 ],
#        [2126.  ],
#        [2103.  ],
#        [2084.8 ],
#        [2095.85],
#        [2074.  ],
#        [2109.7 ],
#        [2079.75],
#        [2054.  ],
#        [2013.7 ],
#        [2048.9 ],
#        [2049.9 ],
#        [2030.  ],
#        [2025.  ],
#        [2004.95],
#        [2046.9 ],
#        [2022.  ],
#        [2006.35],
#        [1961.4 ],
#        [1940.6 ],
#        [1961.  ],
#        [1949.9 ],
#        [1916.4 ],
#        [1919.  ],
#        [1914.45],
#        [1918.9 ],
#        [1962.  ],
#        [1997.2 ],
#        [2008.  ],
#        [2044.5 ],
#        [2036.  ]])

# %%
inputs = inputs.reshape(-1,1)

# %%
inputs  = scaler.transform(inputs)

# %%
inputs.shape
# Out:
# (896, 1)

# %%
X_test = []
for i in range(90,inputs.shape[0]):
    X_test.append(inputs[i-90:i,0])
X_test = np.array(X_test)

# %%
X_test
# Out:
# array([[0.20573331, 0.20514861, 0.20440149, ..., 0.23222349, 0.24518434,
#         0.25059282],
#        [0.20514861, 0.20440149, 0.21211629, ..., 0.24518434, 0.25059282,
#         0.24760435],
#        [0.20440149, 0.21211629, 0.20535975, ..., 0.25059282, 0.24760435,
#         0.24443723],
#        ...,
#        [0.58323859, 0.5750203 , 0.57672568, ..., 0.55202209, 0.56602241,
#         0.57745655],
#        [0.5750203 , 0.57672568, 0.57999025, ..., 0.56602241, 0.57745655,
#         0.58096476],
#        [0.57672568, 0.57999025, 0.57995777, ..., 0.57745655, 0.58096476,
#         0.59282118]])

# %%
X_test.shape
# Out:
# (806, 90)

# %%
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
preds = model.predict(X_test)
preds = scaler.inverse_transform(preds)

# %%
#preds = model.predict(X_test)

# %%
#preds.shape

# %%
#type(scaler)

# %%
#from numpy import int64

#z = np.zeros((806,2), dtype=int64)
#new_preds=np.append(preds, z, axis=1)

# %%
#preds.shape

# %%
#preds_new = np.reshape(preds, (preds.shape[0], 3))

# %%
#predss = scaler.inverse_transform(new_preds)

# %%
#predss.shape

# %%
#predss.shape

# %%
#all_data.shape

# %%
#val = all_data.iloc[4500:,:]

# %%
#df_pred = pd.DataFrame(data=predss, columns=["VWAP", "Volume", "Turnover"])

# %%
#df_pred

# %%
#val.reset_index(drop=True, inplace=True)

# %%
#val

# %%
#val.drop("Date",axis=1)

# %%
#rms=np.sqrt(np.mean(np.power((val.VWAP - df_pred.VWAP),2)))

# %%
#rms

# %%
#train=all_data.iloc[2000:4500,:]
#valid=val.VWAP
#valid['Predictions'] = df_pred.VWAP

# %%
#train.reset_index(drop=True, inplace=True)

# %%
#train

# %%
#valid

# %%
#train['High']

# %%
#valid['High']

# %%
#valid['Predictions']

# %%
#for plotting
train = all_data[2000:4500]
valid = all_data[4500:]
valid['Predictions'] = preds
plt.figure(figsize=(20,8))
plt.plot(all_data)
plt.plot(train['High'],color = 'orange', label = 'Training Price')
plt.plot(valid['High'], color = 'blue', label = 'Validation Price')
plt.plot(valid['Predictions'], color = 'red', label = 'Predicted Price')
plt.title('RELIANCE UNIVARIATE LSTM price prediction')
plt.legend()
plt.show()
